# %% [markdown]
# ### Creating diffrent schema `Bronze`, `Silver` and `Gold`

# %%
# %sql
-- Bronze
CREATE SCHEMA IF NOT EXISTS flightsproj.bronze

# %%
# %sql
-- Silver
CREATE SCHEMA IF NOT EXISTS flightsproj.silver

# %%
# %sql
-- Gold
CREATE SCHEMA IF NOT EXISTS flightsproj.gold

# %% [markdown]
# ### **INCREMENTAL DATA INGESTION**
