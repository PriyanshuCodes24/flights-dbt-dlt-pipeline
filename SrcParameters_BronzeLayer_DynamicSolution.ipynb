# %%
src_array = [
    {'src': 'bookings'},
    {'src': 'airports'},
    {'src': 'passengers'},
    {'src': 'flights'}
]

# %%
dbutils.jobs.taskValues.set(key = 'output_key', value= src_array)

# %% [markdown]
# Now we can create a workflow on top of it to take value from this notebook to dynamic solution
