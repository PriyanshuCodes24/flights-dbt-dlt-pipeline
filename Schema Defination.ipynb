# %% [markdown]
# ### Creating diffrent schema `Bronze`, `Silver` and `Gold`

# %%
# %sql
-- Bronze
CREATE SCHEMA IF NOT EXISTS flightsproj.bronze

# %%
# %sql
-- Silver
CREATE SCHEMA IF NOT EXISTS flightsproj.silver

# %%
# %sql
-- Gold
CREATE SCHEMA IF NOT EXISTS flightsproj.gold

# %% [markdown]
# Creating volumes to all the schemas

# %%
# %sql
-- Bronze Volume
CREATE VOLUME IF NOT EXISTS flightsproj.bronze.bronzevolume

# %%
# %sql
-- Silver Volume
CREATE VOLUME IF NOT EXISTS flightsproj.silver.silvervolume

# %%
# %sql
-- Gold Volume
CREATE VOLUME IF NOT EXISTS flightsproj.gold.goldvolume
