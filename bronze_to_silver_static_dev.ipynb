# %% [markdown]
# Read and understand the data from bronze layer

# %% [markdown]
# ## Bronze → Silver (Static Development Notebook)
#
# This notebook is used for **exploring and validating transformations** on the Bronze data.
# It runs as a normal Spark job and is **not part of the production pipeline**.

# %% [markdown]
# ### Read data from Bronze (batch)

# %%
df = spark.read.format('delta')\
          .load('/Volumes/flightsproj/bronze/bronzevolume/bookings/data')

# %%
display(df)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ### Apply and validate transformations (batch)

# %% [markdown]
# Converting the amount column from string to double

# %%
df = df.withColumn('amount', col('amount').cast('double'))\
     .withColumn('booking_date', to_date(col('booking_date')))

df.printSchema()

# %%
df = df.drop("_rescued_data")

# %%
df.printSchema()

# %%
# Setting the processed timestamp
df = df.withColumn('modified_date', current_timestamp())

# %% [markdown]
# ### Preview final result

# %%
display(df)
